# %% [markdown]
# ## Antes de comenzar

# %%
import os
HOME = os.getcwd()
print(HOME)
DATA_LOCATION = os.path.join(HOME, "data")
print(DATA_LOCATION)
# Out:
# /Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification
# /Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/data

# %%
# Libreria para quitar el resultado de código que no es necesario
# %pip install -q gwpy
! pip install keras==2.3.1
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras==2.3.1 in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: pyyaml in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (from keras==2.3.1) (6.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (from keras==2.3.1) (1.9.1)
# Requirement already satisfied: h5py in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (from keras==2.3.1) (3.7.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (from keras==2.3.1) (1.24.2)
# Requirement already satisfied: six>=1.9.0 in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (from keras==2.3.1) (1.16.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /Users/anesmu/opt/anaconda3/lib/python3.9/site-packages (from keras==2.3.1) (1.0.8)

# %% [markdown]
# ## Instalación YOLOv8
#
# ⚠️ **DISCLAIMER** -> YOLOv8 está aún en pleno desarrollo. Y se introducen cambios casi semanalmente. Lo que podría llevar a errores en el cuaderno.

# %%
# %pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.118 🚀 Python-3.11.3 torch-2.0.1 CPU
# Setup complete ✅ (10 CPUs, 64.0 GB RAM, 254.9/1858.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# # Comienza el entrenamiento

# %%
# !yolo task=classify mode=train model=yolov8m-cls.pt data={HOME}/data epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.13 torch-1.13.1 CPU
# yolo/engine/trainer: task=classify, mode=train, model=yolov8m-cls.yaml, data=/Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/data, epochs=100, patience=50, batch=16, imgsz=640, save=True, cache=False, device=, workers=16, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.1, lrf=0.01, momentum=0.937, weight_decay=0.0001, warmup_epochs=0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.1, nbs=256, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/classify/train
# Overriding model.yaml nc=1000 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.Conv                  [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.Conv                  [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.C2f                   [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.Conv                  [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.C2f                   [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.Conv                  [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.C2f                   [384, 384, 4, True]
#   7                  -1  1   2655744  ultralytics.nn.modules.Conv                  [384, 768, 3, 2]
#   8                  -1  2   7084032  ultralytics.nn.modules.C2f                   [768, 768, 2, True]
#   9                  -1  1    993286  ultralytics.nn.modules.Classify              [768, 6]
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv8m-cls summary: 141 layers, 15780022 parameters, 15780022 gradients, 41.9 GFLOPs
# optimizer: SGD(lr=0.1) with parameter groups 38 weight(decay=0.0), 39 weight(decay=0.0001), 39 bias
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to runs/classify/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100         0G    0.08735          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.186          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100         0G     0.1001          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.104      0.854
#
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100         0G     0.1437          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.361      0.896
#
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100         0G    0.08632          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.264      0.886
#
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100         0G     0.0758          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.432      0.889
#
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100         0G    0.04852          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.639      0.939
#
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100         0G    0.04293          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.682          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100         0G    0.04144          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.621          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100         0G    0.03345          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.679          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100         0G    0.02951          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all        0.6          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100         0G    0.02448          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all        0.7          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100         0G    0.02244          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.793          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100         0G    0.01595          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.814          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100         0G    0.01301          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.925          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100         0G   0.008316          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.904          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100         0G   0.007166          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100         0G   0.007316          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.911          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100         0G   0.004376          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100         0G   0.003077          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.936          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100         0G   0.002531          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100         0G   0.002356          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100         0G   0.001425          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.939          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100         0G   0.001317          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100         0G   0.003349          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100         0G    0.00118          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100         0G   0.001525          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100         0G   0.002053          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100         0G  0.0009413          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100         0G  0.0008532          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100         0G  0.0009768          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100         0G  0.0008901          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.929          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100         0G   0.002199          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100         0G  0.0009774          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100         0G   0.002485          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100         0G  0.0005787          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100         0G  0.0009103          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100         0G   0.001298          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100         0G   0.001971          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100         0G  0.0003946          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      40/100         0G  0.0005259          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      41/100         0G  0.0003464          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      42/100         0G   0.000586          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      43/100         0G  0.0006452          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      44/100         0G  0.0007223          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      45/100         0G  0.0001853          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      46/100         0G  0.0001871          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.975          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      47/100         0G   0.000105          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      48/100         0G  0.0005682          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      49/100         0G  0.0004042          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      50/100         0G  0.0005752          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#      51/100         0G  0.0002376          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#      52/100         0G  0.0004574          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.957      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#      53/100         0G  0.0002176          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.954      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#      54/100         0G  0.0002244          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:09<00:00,
#                    all      0.954      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#      55/100         0G  0.0002253          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      56/100         0G   0.000207          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.971      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#      57/100         0G  0.0001686          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      58/100         0G   0.000222          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      59/100         0G   0.000157          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#      60/100         0G  0.0002215          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      61/100         0G  0.0001169          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      62/100         0G  0.0003732          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.975          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      63/100         0G  0.0004347          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      64/100         0G  0.0001319          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      65/100         0G  0.0003151          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      66/100         0G  0.0003682          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.936          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      67/100         0G  0.0002027          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      68/100         0G  0.0001313          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      69/100         0G  0.0002498          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      70/100         0G  0.0003749          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      71/100         0G  0.0001633          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      72/100         0G  0.0001181          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      73/100         0G  0.0005602          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      74/100         0G  0.0006532          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      75/100         0G  6.918e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      76/100         0G  0.0003094          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      77/100         0G  0.0002667          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      78/100         0G  7.871e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      79/100         0G  0.0003808          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      80/100         0G  0.0001246          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      81/100         0G  8.251e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      82/100         0G  4.241e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      83/100         0G  6.165e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:09<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      84/100         0G  3.024e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      85/100         0G  6.438e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      86/100         0G   0.000189          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      87/100         0G  0.0005559          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      88/100         0G  6.112e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.957          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      89/100         0G  0.0002176          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:09<00:00,
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      90/100         0G  0.0001377          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
# Closing dataloader mosaic
#
#       Epoch    GPU_mem       loss  Instances       Size
#      91/100         0G  0.0001358          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      92/100         0G   5.56e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      93/100         0G  3.707e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      94/100         0G  4.934e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      95/100         0G  0.0001851          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      96/100         0G   4.31e-05          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:08<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      97/100         0G  0.0001146          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      98/100         0G  0.0001094          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      99/100         0G  0.0001944          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     100/100         0G   0.000212          5        224: 100%|██████████| 69/69
#                classes   top1_acc   top5_acc: 100%|██████████| 5/5 [00:07<00:00,
#                    all      0.964          1
#
# 100 epochs completed in 4.077 hours.
# Optimizer stripped from runs/classify/train/weights/last.pt, 31.7MB
# Optimizer stripped from runs/classify/train/weights/best.pt, 31.7MB
# Results saved to runs/classify/train

# %% [markdown]
# # Exportar modelo a Core ML para usarlo en iOS

# %%
# %pip install coremltools
# Out:
# Collecting coremltools
#   Downloading coremltools-6.3.0.tar.gz (941 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 941.9/941.9 kB 5.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.5 in /opt/homebrew/lib/python3.11/site-packages (from coremltools) (1.24.3)
# Collecting protobuf<=4.0.0,>=3.1.0
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from coremltools) (1.12)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from coremltools) (4.65.0)
# Requirement already satisfied: packaging in /Users/anesmu/Library/Python/3.11/lib/python/site-packages (from coremltools) (23.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->coremltools) (1.3.0)
# Building wheels for collected packages: coremltools
#   Building wheel for coremltools (setup.py) ... done
#   Created wheel for coremltools: filename=coremltools-6.3.0-py3-none-any.whl size=1220313 sha256=517cd50cf98eb1d1a96da1c5360501eff4d13b265881b7640fc24bd2486b5a9c
#   Stored in directory: /Users/anesmu/Library/Caches/pip/wheels/a4/a4/28/b762e8b36896df0ab7632cf75c6c2da3ea108352da0d46b79d
# Successfully built coremltools
# Installing collected packages: protobuf, coremltools
# Successfully installed coremltools-6.3.0 protobuf-3.20.3
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !yolo export model={HOME}/runs/classify/train/weights/best.pt format=coreml nms
# Out:
# Ultralytics YOLOv8.0.118 🚀 Python-3.11.3 torch-2.0.1 CPU
# YOLOv8m-cls summary (fused): 103 layers, 15770342 parameters, 0 gradients
#
# PyTorch: starting from /Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/runs/classify/train/weights/best.pt with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 6) (30.2 MB)
# Torch version 2.0.1 has not been tested with coremltools. You may run into unexpected errors. Torch 2.0.0 is the most recent version that has been tested.
#
# CoreML: starting export with coremltools 6.3.0...
# Converting PyTorch Frontend ==> MIL Ops: 100%|▉| 317/318 [00:00<00:00, 13065.21
# Running MIL frontend_pytorch pipeline: 100%|█| 5/5 [00:00<00:00, 1222.19 passes/
# Running MIL default pipeline: 100%|███████| 56/56 [00:00<00:00, 728.46 passes/s]
# Running MIL backend_neuralnetwork pipeline: 100%|█| 8/8 [00:00<00:00, 3236.35 pa
# Translating MIL ==> NeuralNetwork Ops: 100%|█| 355/355 [00:06<00:00, 58.66 ops/s
# CoreML: export success ✅ 73.8s, saved as /Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/runs/classify/train/weights/best.mlmodel (60.2 MB)
#
# Export complete (74.1s)
# Results saved to /Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/runs/classify/train/weights
# Predict:         yolo predict task=classify model=/Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/runs/classify/train/weights/best.mlmodel imgsz=224
# Validate:        yolo val task=classify model=/Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/runs/classify/train/weights/best.mlmodel imgsz=224 data=/Users/anesmu/Desktop/TFG/SIGN_GENIUS_IA/yolo8_hand_classification/data
# Visualize:       https://netron.app
